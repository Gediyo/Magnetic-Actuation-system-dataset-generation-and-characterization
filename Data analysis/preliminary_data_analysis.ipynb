# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('24-07-2024_20-02-49_Coil_table_data.csv', index_col=0)

df.index = pd.to_datetime(df.index, format="%d-%m-%Y_%H-%M-%S")

df = df.resample('s').mean()

# Calculate the 3-period running average
df['Running_Avg_coilTemp_5'] = df['msdCoilTemp_5(degC)'].rolling(window=10).mean()

df['Running_Avg_coilTemp_1'] = df['msdCoilTemp_1(degC)'].rolling(window=10).mean()

df['Running_Avg_coilTemp_3'] = df['msdCoilTemp_3(degC)'].rolling(window=10).mean()
df['Running_Avg_coilTemp_4'] = df['msdCoilTemp_4(degC)'].rolling(window=10).mean()
df['Running_Avg_coilTemp_7'] = df['msdCoilTemp_7(degC)'].rolling(window=10).mean()
df['Running_Avg_coilTemp_8'] = df['msdCoilTemp_8(degC)'].rolling(window=10).mean()

# %%
df13 = df[df["cmdCoilCurrent_1(A)"]>=13]

# %%
print(df13['msdCoilCurrent_1(A)'].max())
print(df13['msdCoilCurrent_1(A)'].min())
print(df13['msdCoilCurrent_1(A)'].mean())
print((df13['msdCoilCurrent_1(A)'].max()- df13['msdCoilCurrent_1(A)'].min())/2)
# Out:
# 13.27638635625
# 11.8733505625
# 12.943696687148577
# 0.701517896875

# %%
df.head()
# Out:
#                      cmdCoilCurrent_1(A)  cmdCoilCurrent_2(A)  \
# TimeStamp
# 2024-07-24 20:02:49                  0.0                  0.0
# 2024-07-24 20:02:50                  0.0                  0.0
# 2024-07-24 20:02:51                  0.0                  0.0
# 2024-07-24 20:02:52                  0.0                  0.0
# 2024-07-24 20:02:53                  0.0                  0.0
#
#                      cmdCoilCurrent_3(A)  cmdCoilCurrent_4(A)  \
# TimeStamp
# 2024-07-24 20:02:49                  0.0                  0.0
# 2024-07-24 20:02:50                  0.0                  0.0
# 2024-07-24 20:02:51                  0.0                  0.0
# 2024-07-24 20:02:52                  0.0                  0.0
# 2024-07-24 20:02:53                  0.0                  0.0
#
#                      cmdCoilCurrent_5(A)  cmdCoilCurrent_6(A)  \
# TimeStamp
# 2024-07-24 20:02:49                  0.0                  0.0
# ...

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.plot(df.index, df['cmdCoilCurrent_5(A)'],  linestyle='-', color='b')
ax1.set_xlabel('Time (Hr:min)', fontsize=16)
ax1.set_ylabel('Command current [A]', color='b', fontsize=16)
ax1.tick_params(axis='y', labelcolor='b', labelsize=12)
ax1.tick_params(axis='x', rotation=45, labelsize=12)

# Format the x-axis to show only hour and minute
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
#ax1.xaxis.set_major_locator(mdates.HourLocator(interval=1))  # Adjust the interval as needed

# Create a secondary y-axis
ax2 = ax1.twinx()  # This creates a new Axes instance sharing the same x-axis
ax2.plot(df.index, df['Running_Avg_coilTemp_4'], linestyle='-', color='r')
ax2.set_ylabel('Running avg. coil temperature [degC]', color='r', fontsize=16)
ax2.tick_params(axis='y', labelcolor='r', labelsize=12) 

plt.title('Running Average coil temperature relative to command current  (Coil #5)', fontsize=18)
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Optional: add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()  # Adjust layout to make sure everything fits
plt.show()
# Out:
# C:\Users\Gediy\AppData\Local\Temp\ipykernel_7244\174600359.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend(loc='upper left')
# C:\Users\Gediy\AppData\Local\Temp\ipykernel_7244\174600359.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(loc='upper right')

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.plot(df.index, df['cmdCoilCurrent_1(A)'],  linestyle='-', color='black', label ='coil 1 cmdCurrent')
ax1.plot(df.index, df['cmdCoilCurrent_2(A)'],  linestyle='--', color='y', label ='coil 2 cmdCurrent')
ax1.plot(df.index, df['cmdCoilCurrent_4(A)'],  linestyle='--', color='m', label ='coil 4 cmdCurrent')
ax1.plot(df.index, df['cmdCoilCurrent_5(A)'],  linestyle='--', color='b', label ='coil 5 cmdCurrent')
ax1.set_xlabel('Time (Hr:min)', fontsize=16)
ax1.set_ylabel('Command current [A]', color='k', fontsize=16)
ax1.tick_params(axis='y', labelcolor='k', labelsize=12)
ax1.tick_params(axis='x', rotation=45, labelsize=12)

# Format the x-axis to show only hour and minute
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
#ax1.xaxis.set_major_locator(mdates.HourLocator(interval=1))  # Adjust the interval as needed


# Set custom limits for the primary y-axis
ax1.set_ylim(-3, 25)  # Example range for Value1

# Create a secondary y-axis
ax2 = ax1.twinx()  # This creates a new Axes instance sharing the same x-axis
ax2.plot(df.index, df['msdCoilCurrent_1(A)'], linestyle='-', color='g', label ='coil 1 msdCurrent')
ax2.set_ylabel('Measured Current [A]', color='g', fontsize=16)
ax2.tick_params(axis='y', labelcolor='g', labelsize=12)

plt.title('Command vs measured current for coil 1', fontsize=18)
plt.grid(True)


# Set custom limits for the primary y-axis
ax2.set_ylim(-3, 25)  # Example range for Value1

# Optional: add legends
ax1.legend(loc='upper left', fontsize=12)
ax2.legend(loc='upper right', fontsize=12)

plt.tight_layout()  # Adjust layout to make sure everything fits
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.plot(df.index, df['msdCoilTemp_1(degC)'],  linestyle='-', color='black', label ='coil 1 Temp')
ax1.plot(df.index, df['msdCoilTemp_2(degC)'],  linestyle='-', color='b', label ='coil 2 Temp')
ax1.plot(df.index, df['msdCoilTemp_3(degC)'],  linestyle='-', color='g', label ='coil 3 Temp')
ax1.plot(df.index, df['msdCoilTemp_4(degC)'],  linestyle='-', color='r', label ='coil 4 Temp')
ax1.plot(df.index, df['msdCoilTemp_5(degC)'],  linestyle='-', color='c', label ='coil 5 Temp')
ax1.plot(df.index, df['msdCoilTemp_6(degC)'],  linestyle='-', color='m', label ='coil 6 Temp')
ax1.plot(df.index, df['msdCoilTemp_7(degC)'],  linestyle='-', color='y', label ='coil 7 Temp')
ax1.plot(df.index, df['msdCoilTemp_8(degC)'],  linestyle='-', color='0.8', label ='coil 8 Temp')
ax1.set_xlabel('Time')
ax1.set_ylabel('Command current [A]', color='k')
ax1.tick_params(axis='y', labelcolor='k')

# Set custom limits for the primary y-axis
#ax1.set_ylim(-25, 25)  # Example range for Value1

# Create a secondary y-axis
# ax2 = ax1.twinx()  # This creates a new Axes instance sharing the same x-axis
# ax2.plot(df.index, df['msdCoilCurrent_5(A)'], linestyle='-', color='g', label ='coil 5 msdCurrent')
# ax2.set_ylabel('Measured Current [A]', color='g')
# ax2.tick_params(axis='y', labelcolor='g')

plt.title('Command vs measured current for coil 1')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Set custom limits for the primary y-axis
# ax2.set_ylim(-25, 25)  # Example range for Value1

# Optional: add legends
ax1.legend(loc='upper left')
# ax2.legend(loc='upper right')

plt.tight_layout()  # Adjust layout to make sure everything fits
plt.show()
